# %% [markdown]
# <a href="https://colab.research.google.com/github/tanvipathak/Cppcodes/blob/master/Computer_Vision_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
from PIL import Image

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
img=Image.open('/content/gdrive/My Drive/Colab Notebooks/Cheers.png')

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=940x788 at 0x7F9D0EB76128>

# %%
img. rotate(180)
# Out:
# <PIL.Image.Image image mode=RGBA size=940x788 at 0x7F9D0EB76CF8>

# %%
img.rotate(180)
# Out:
# <PIL.Image.Image image mode=RGBA size=940x788 at 0x7F9D0D1DF128>

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=940x788 at 0x7F9D0EB76128>

# %%
type(img)
# Out:
# PIL.PngImagePlugin.PngImageFile

# %%
img_arr=np.asarray(img)

# %%
type(img_arr)
# Out:
# numpy.ndarray

# %%
img_arr.shape
plt.imshow(img_arr)

# %%
img_test=img_arr.copy()
img_test2=img_arr.copy()

# %%
plt.imshow(img_test2[:,:,1]) #red channel at 0 green at 1 and blue at 2
#plt.imshow(img_test[:,:,0], cmap='gray')
#plt.imshow(img_test2[:,:,0])
#plt.imshow(img_test2[:,:,2])

# %%
img_test[:,:,0]=0 #removes red channel
plt.imshow(img_test)
